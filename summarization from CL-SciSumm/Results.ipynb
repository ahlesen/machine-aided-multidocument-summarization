# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt

# %% [markdown]
# ## top-1

# %% [markdown]
# ### xgboost

# %%
# only w2v features +seq_+ f1_feat+hdp+lda
xgboost_indices = ['all']
xgboost = [[0.19324836251909452, 0.31241529455647604, 0.1579678258162968]]

# %%
xgboost_indices.append('w2v_seq_rouge_f1')
xgboost.append([0.1982530602605909, 0.3372880651527327, 0.17542565169001512])

# %%
xgboost_indices.append('w2v_seq')
xgboost.append([0.21157892678256546, 0.31760102707938975, 0.18469409975970102])

# %%
xgboost_indices.append('w2v')
xgboost.append([0.19954038701545704, 0.3233288424347874, 0.149570976438548])

# %%
xgboost_indices.append('hdp_lda')
xgboost.append([0.19662945624424172, 0.32426136179171317, 0.15410472639000478])

# %%
xgboost_indices.append('hdp')
xgboost.append([0.20291673197138813, 0.3060764146373976, 0.17352097059644137])

# %%
xgboost_indices.append('lda')
xgboost.append([0.1947858153472447, 0.3096493178154836, 0.16517953946560632])

# %%
xgboost_indices.append('jac')
xgboost.append([0.2179759324593234, 0.30681668646050453, 0.17877269627840794])

# %%
xgboost_indices.append('baseline')
xgboost.append([0.22951831953767093, 0.3110868759978951, 0.17520002466856807])

# %%
len(xgboost_indices)
# Out:
# 9

# %%
len(xgboost)
# Out:
# 9

# %%
xgboost_indices = ['xgboost_'+s for s in xgboost_indices]
xgboost = [val + ['xgboost'] for val in xgboost]
xgboost_df = pd.DataFrame(np.array(xgboost),
                    columns=['abstract', 'community', 'human','method'])
xgboost_df.index = xgboost_indices

# %%
xgboost_df
# Out:
#                                      abstract            community  \
# xgboost_all               0.19324836251909452  0.31241529455647604
# xgboost_w2v_seq_rouge_f1   0.1982530602605909   0.3372880651527327
# xgboost_w2v_seq           0.21157892678256546  0.31760102707938975
# xgboost_w2v               0.19954038701545704   0.3233288424347874
# xgboost_hdp_lda           0.19662945624424172  0.32426136179171317
# xgboost_hdp               0.20291673197138813   0.3060764146373976
# xgboost_lda                0.1947858153472447   0.3096493178154836
# xgboost_jac                0.2179759324593234  0.30681668646050453
# xgboost_baseline          0.22951831953767093   0.3110868759978951
#
#                                         human   method
# xgboost_all                0.1579678258162968  xgboost
# xgboost_w2v_seq_rouge_f1  0.17542565169001512  xgboost
# xgboost_w2v_seq           0.18469409975970102  xgboost
# xgboost_w2v                 0.149570976438548  xgboost
# ...

# %% [markdown]
# ### catboost

# %%
catboost_indices = ['all',
 'w2v_seq_rouge_f1',
 'w2v_seq',
 'hdp_lda',
 'hdp',
 'lda',
 'jac']

# %%
catboost = [[0.2511979310967296, 0.28882339888771347, 0.18636222070100222]]

# %%
catboost.append([0.2340680811961347, 0.3393195285789483, 0.20316824858832608])

# %%
catboost.append([0.2335245698609633, 0.3589430951751397, 0.16606803459535394])

# %%
catboost.append([0.24975778386411546, 0.32898824520173875, 0.20797752277229575])

# %%
catboost.append([0.24286631832422448, 0.32015983370924594, 0.19824910801274004])

# %%
catboost.append([0.24591310678310588, 0.30130490782111224, 0.18286560271292993])

# %%
catboost.append([0.19420697343739707, 0.27979162434216764, 0.1526580795590468])

# %%
len(catboost_indices),len(catboost)
# Out:
# (7, 7)

# %%
catboost_indices = ['catboost_'+s for s in catboost_indices]
catboost = [val + ['catboost'] for val in catboost]
catboost_df = pd.DataFrame(np.array(catboost),
                    columns=['abstract', 'community', 'human','method'])
catboost_df.index = catboost_indices

# %%
catboost_df
# Out:
#                                       abstract            community  \
# catboost_all                0.2511979310967296  0.28882339888771347
# catboost_w2v_seq_rouge_f1   0.2340680811961347   0.3393195285789483
# catboost_w2v_seq            0.2335245698609633   0.3589430951751397
# catboost_hdp_lda           0.24975778386411546  0.32898824520173875
# catboost_hdp               0.24286631832422448  0.32015983370924594
# catboost_lda               0.24591310678310588  0.30130490782111224
# catboost_jac               0.19420697343739707  0.27979162434216764
#
#                                          human    method
# catboost_all               0.18636222070100222  catboost
# catboost_w2v_seq_rouge_f1  0.20316824858832608  catboost
# catboost_w2v_seq           0.16606803459535394  catboost
# catboost_hdp_lda           0.20797752277229575  catboost
# catboost_hdp               0.19824910801274004  catboost
# catboost_lda               0.18286560271292993  catboost
# ...

# %% [markdown]
# ### SVM with rbf

# %%
svm_indices= ['baseline']

# %%
svm = [[0.07787471817756389, 0.14078694078267812, 0.10140411466064743]]

# %%
svm_indices = ['svm_'+s for s in svm_indices]
svm = [val + ['svm'] for val in svm]
svm_df = pd.DataFrame(np.array(svm),
                    columns=['abstract', 'community', 'human','method'])
svm_df.index = svm_indices

# %%
svm_df
# Out:
#                          abstract            community                human  \
# svm_baseline  0.07787471817756389  0.14078694078267812  0.10140411466064743
#
#              method
# svm_baseline    svm

# %% [markdown]
# ### MLPClassifier

# %%
xgboost_indices
# Out:
# ['xgboost_all',
#  'xgboost_w2v_seq_rouge_f1',
#  'xgboost_w2v_seq',
#  'xgboost_w2v',
#  'xgboost_hdp_lda',
#  'xgboost_hdp',
#  'xgboost_lda',
#  'xgboost_jac',
#  'xgboost_baseline']

# %%
MLP_indices = ['all',
 'w2v_seq_rouge_f1',
 'w2v_seq',
 'w2v',
 'hdp_lda',
 'hdp',
 'lda',
 'jac',
 'baseline']

# %%
MLP = [[0.30749446736618434, 0.3390272849676415, 0.19407388766975493]]

# %%
MLP.append([0.2878034209847514, 0.3060272572233433, 0.1815719998672054])

# %%
MLP.append([0.2830997495789881, 0.3185983338645845, 0.19646041677958894])

# %%
MLP.append([0.28513537303066505, 0.32439938426629594, 0.19037373170853195])

# %%
MLP.append([0.30600373616405746, 0.31834343132677434, 0.22430687418319506])

# %%
MLP.append([0.29837009283880433, 0.33578335345737853, 0.18129473949889643])

# %%
MLP.append([0.27280657818100984, 0.31921975917920653, 0.17620671453840597])

# %%
MLP.append([0.21971719889722582, 0.2822074493460799, 0.13555569664438108])

# %%
MLP.append([0.26870249097141874, 0.3003938411164929, 0.17075949648590674])

# %%
len(MLP_indices),len(MLP)
# Out:
# (9, 9)

# %%
MLP_indices = ['MLP_'+s for s in MLP_indices]
MLP = [val + ['MLP'] for val in MLP]
MLP_df = pd.DataFrame(np.array(MLP),
                    columns=['abstract', 'community', 'human','method'])
MLP_df.index = MLP_indices

# %%
MLP_df
# Out:
#                                  abstract            community  \
# MLP_all               0.30749446736618435   0.3390272849676415
# MLP_w2v_seq_rouge_f1   0.2878034209847514   0.3060272572233433
# MLP_w2v_seq            0.2830997495789881   0.3185983338645845
# MLP_w2v               0.28513537303066505  0.32439938426629594
# MLP_hdp_lda           0.30600373616405746  0.31834343132677434
# MLP_hdp               0.29837009283880433  0.33578335345737853
# MLP_lda               0.27280657818100984  0.31921975917920653
# MLP_jac               0.21971719889722582   0.2822074493460799
# MLP_baseline          0.26870249097141874   0.3003938411164929
#
#                                     human method
# MLP_all               0.19407388766975492    MLP
# MLP_w2v_seq_rouge_f1   0.1815719998672054    MLP
# MLP_w2v_seq           0.19646041677958895    MLP
# MLP_w2v               0.19037373170853195    MLP
# MLP_hdp_lda           0.22430687418319506    MLP
# ...

# %% [markdown]
# ## Top-k

# %% [markdown]
# xgboost

# %%
xgboost_top_3_indices = ['all','hdp_lda']
xgboost_top_3 = [[0.29078129374670153, 0.3646400300537678, 0.20672613209210627]]

# %%
xgboost_top_3.append([0.28131673157878145, 0.3729616123426012, 0.21540396886013197])

# %%
xgboost_top_3_indices = ['xgboost_top_3_'+s for s in xgboost_top_3_indices]
xgboost_top_3 = [val + ['xgboost'] for val in xgboost_top_3]
xgboost_top_3_df = pd.DataFrame(np.array(xgboost_top_3),
                    columns=['abstract', 'community', 'human','method'])
xgboost_top_3_df.index = xgboost_top_3_indices

# %%
xgboost_top_3_df
# Out:
#                                   abstract           community  \
# xgboost_top_3_all      0.29078129374670153  0.3646400300537678
# xgboost_top_3_hdp_lda  0.28131673157878145  0.3729616123426012
#
#                                      human   method
# xgboost_top_3_all      0.20672613209210627  xgboost
# xgboost_top_3_hdp_lda  0.21540396886013197  xgboost

# %% [markdown]
# catboost

# %%
catboost_top_3_indices = ['all','hdp_lda']
catboost_top_3 = [[0.27130789793014474, 0.33627280522719694, 0.21403042532207833]]

# %%
catboost_top_3.append([0.2726377822948509, 0.3381632671982172, 0.23864429378536958])

# %%
catboost_top_3_indices = ['catboost_top_3_'+s for s in catboost_top_3_indices]
catboost_top_3 = [val + ['catboost'] for val in catboost_top_3]
catboost_top_3_df = pd.DataFrame(np.array(catboost_top_3),
                    columns=['abstract', 'community', 'human','method'])
catboost_top_3_df.index = catboost_top_3_indices

# %%
catboost_top_3_df
# Out:
#                                    abstract            community  \
# catboost_top_3_all      0.27130789793014476  0.33627280522719694
# catboost_top_3_hdp_lda   0.2726377822948509   0.3381632671982172
#
#                                       human    method
# catboost_top_3_all      0.21403042532207833  catboost
# catboost_top_3_hdp_lda  0.23864429378536958  catboost

# %% [markdown]
# MLPClassifier

# %%
MLP_top_3_indices = ['all','hdp_lda']
MLP_top_3 = [[0.30953123279875486, 0.3733387880160248, 0.2198220265613308]]

# %%
MLP_top_3.append([0.30656146405960243, 0.4053192644616913, 0.22887144739488954])

# %%
MLP_top_3_indices = ['MLP_top_3_'+s for s in MLP_top_3_indices]
MLP_top_3 = [val + ['MLP'] for val in MLP_top_3]
MLP_top_3_df = pd.DataFrame(np.array(MLP_top_3),
                    columns=['abstract', 'community', 'human','method'])
MLP_top_3_df.index = MLP_top_3_indices

# %%
MLP_top_3_df
# Out:
#                               abstract           community  \
# MLP_top_3_all       0.3095312327987549  0.3733387880160248
# MLP_top_3_hdp_lda  0.30656146405960244  0.4053192644616913
#
#                                  human method
# MLP_top_3_all       0.2198220265613308    MLP
# MLP_top_3_hdp_lda  0.22887144739488954    MLP

# %%
best_2018 = [0.329,0.252,0.213, 'best_2018']
best_2018_df = pd.DataFrame(np.array([best_2018]),
                    columns=['abstract', 'community', 'human','method'])
best_2018_df.index = ['best_2018']

# %%
best_2018_df
# Out:
#           abstract community  human     method
# best_2018    0.329     0.252  0.213  best_2018

# %% [markdown]
# ## FINAL

# %%
frames = [xgboost_df[0:1],xgboost_df[4:5],catboost_df[0:1],catboost_df[4:5],MLP_df[0:1],MLP_df[4:5],best_2018_df,xgboost_top_3_df, catboost_top_3_df, MLP_top_3_df]

# %%
frames_top_1 = [xgboost_df,catboost_df,svm_df,MLP_df,best_2018_df]

# %%
frames_top_3 = [xgboost_top_3_df, catboost_top_3_df, MLP_top_3_df,best_2018_df]

# %%
result_top_3 = pd.concat(frames_top_3)

# %%
result_top_1 = pd.concat(frames_top_1)

# %%
result = pd.concat(frames)

# %%
result
# Out:
#                                    abstract            community  \
# xgboost_all             0.19324836251909452  0.31241529455647604
# xgboost_hdp_lda         0.19662945624424172  0.32426136179171317
# catboost_all             0.2511979310967296  0.28882339888771347
# catboost_hdp            0.24286631832422448  0.32015983370924594
# MLP_all                 0.30749446736618435   0.3390272849676415
# MLP_hdp_lda             0.30600373616405746  0.31834343132677434
# best_2018                             0.329                0.252
# xgboost_top_3_all       0.29078129374670153   0.3646400300537678
# xgboost_top_3_hdp_lda   0.28131673157878145   0.3729616123426012
# catboost_top_3_all      0.27130789793014476  0.33627280522719694
# catboost_top_3_hdp_lda   0.2726377822948509   0.3381632671982172
# MLP_top_3_all            0.3095312327987549   0.3733387880160248
# MLP_top_3_hdp_lda       0.30656146405960244   0.4053192644616913
#
#                                       human     method
# ...

# %% [markdown]
# abstract

# %%
result.sort_values(by='abstract',ascending=False)
# Out:
#                                    abstract            community  \
# best_2018                             0.329                0.252
# MLP_top_3_all            0.3095312327987549   0.3733387880160248
# MLP_all                 0.30749446736618435   0.3390272849676415
# MLP_top_3_hdp_lda       0.30656146405960244   0.4053192644616913
# MLP_hdp_lda             0.30600373616405746  0.31834343132677434
# xgboost_top_3_all       0.29078129374670153   0.3646400300537678
# xgboost_top_3_hdp_lda   0.28131673157878145   0.3729616123426012
# catboost_top_3_hdp_lda   0.2726377822948509   0.3381632671982172
# catboost_top_3_all      0.27130789793014476  0.33627280522719694
# catboost_all             0.2511979310967296  0.28882339888771347
# catboost_hdp            0.24286631832422448  0.32015983370924594
# xgboost_hdp_lda         0.19662945624424172  0.32426136179171317
# xgboost_all             0.19324836251909452  0.31241529455647604
#
#                                       human     method
# ...

# %%
plt.rcParams['figure.figsize'] = (10, 6)

# %%
plt.rcParams.update({'font.size': 20})

# %%
clrs = []
for res in result_top_1['abstract'].sort_values(ascending=False).index:
    if 'best' in res:
        clrs.append('Yes')
    else:
        clrs.append('No')
color_dict = {'Yes':'green', 'No':'blue'}
result_top_1['abstract'].sort_values(ascending=False).astype(float).plot.bar(x='models',y='Rouge-2-f1',title='System summaries vs Paper Abstracts',grid=True, color=[color_dict[r] for r in clrs])
plt.ylabel('Rouge-2-f1')
plt.xlabel('models')
plt.show()
list(result_top_1['abstract'].sort_values(ascending=False).index[:3])
# Out:
# ['best_2018', 'MLP_all', 'MLP_hdp_lda']

# %%
clrs = []
for res in result_top_1['community'].sort_values(ascending=False).index:
    if 'best' in res:
        clrs.append('Yes')
    else:
        clrs.append('No')
color_dict = {'Yes':'green', 'No':'blue'}
result_top_1['community'].sort_values(ascending=False).astype(float).plot.bar(x='models',y='Rouge-2-f1',title='System summaries vs Community summaries',grid=True, color=[color_dict[r] for r in clrs])
plt.ylabel('Rouge-2-f1')
plt.xlabel('models')
plt.show()
list(result_top_1['community'].sort_values(ascending=False).index[:3])
# Out:
# ['catboost_w2v_seq', 'catboost_w2v_seq_rouge_f1', 'MLP_all']

# %%
clrs = []
for res in result_top_1['human'].sort_values(ascending=False).index:
    if 'best' in res:
        clrs.append('Yes')
    else:
        clrs.append('No')
color_dict = {'Yes':'green', 'No':'blue'}
result_top_1['human'].sort_values(ascending=False).astype(float).plot.bar(x='models',y='Rouge-2-f1',title='System summaries vs. Human summaries',grid=True, color=[color_dict[r] for r in clrs])
plt.ylabel('Rouge-2-f1')
plt.xlabel('models')
plt.show()
list(result_top_1['human'].sort_values(ascending=False).index[:3])
# Out:
# ['MLP_hdp_lda', 'best_2018', 'catboost_hdp_lda']

# %% [markdown]
# ## top-1 with top-3

# %%
clrs = []
for res in result['abstract'].sort_values(ascending=False).index:
    if 'top_3' in res:
        clrs.append('Yes')
    elif 'best' in res:
        clrs.append('best')
    else:
        clrs.append('No')
color_dict = {'Yes':'red', 'No':'blue','best':'green'}
bars = result['abstract'].sort_values(ascending=False).astype(float).plot.bar(x='models',y='Rouge-2-f1',title='System summaries vs Paper Abstracts',grid=True, color=[color_dict[r] for r in clrs])
plt.ylabel('Rouge-2-f1')
plt.xlabel('models')
plt.show()
list(result['abstract'].sort_values(ascending=False).index[:3])
# Out:
# ['best_2018', 'MLP_top_3_all', 'MLP_all']

# %%
kek = result['abstract'].sort_values(ascending=False).astype(float)
for (i, j),ind in zip(enumerate(kek),kek.index):
    print(i,ind, j)
# Out:
# 0 best_2018 0.329
# 1 MLP_top_3_all 0.3095312327987549
# 2 MLP_all 0.30749446736618435
# 3 MLP_top_3_hdp_lda 0.30656146405960244
# 4 MLP_hdp_lda 0.30600373616405746
# 5 xgboost_top_3_all 0.29078129374670153
# 6 xgboost_top_3_hdp_lda 0.28131673157878145
# 7 catboost_top_3_hdp_lda 0.2726377822948509
# 8 catboost_top_3_all 0.27130789793014476
# 9 catboost_all 0.2511979310967296
# 10 catboost_hdp 0.24286631832422448
# 11 xgboost_hdp_lda 0.19662945624424172
# 12 xgboost_all 0.19324836251909452

# %%
(kek.values[1]/kek.values[2]+kek.values[3]/kek.values[4]+kek.values[5]/kek.values[12]+kek.values[6]/kek.values[11]+kek.values[7]/kek.values[10]+kek.values[8]/kek.values[9]-6)/6
# Out:
# 0.1910806043147879

# %%
clrs = []
for res in result['community'].sort_values(ascending=False).index:
    if 'top_3' in res:
        clrs.append('Yes')
    elif 'best' in res:
        clrs.append('best')
    else:
        clrs.append('No')
color_dict = {'Yes':'red', 'No':'blue','best':'green'}
bars = result['community'].sort_values(ascending=False).astype(float).plot.bar(x='models',y='Rouge-2-f1',title='System summaries vs Community summaries',grid=True, color=[color_dict[r] for r in clrs])
plt.ylabel('Rouge-2-f1')
plt.xlabel('models')
plt.show()
list(result['community'].sort_values(ascending=False).index[:3])
# Out:
# ['MLP_top_3_hdp_lda', 'MLP_top_3_all', 'xgboost_top_3_hdp_lda']

# %%
kek = result['community'].sort_values(ascending=False).astype(float)
for (i, j),ind in zip(enumerate(kek),kek.index):
    print(i,ind, j)
# Out:
# 0 MLP_top_3_hdp_lda 0.4053192644616913
# 1 MLP_top_3_all 0.3733387880160248
# 2 xgboost_top_3_hdp_lda 0.3729616123426012
# 3 xgboost_top_3_all 0.3646400300537678
# 4 MLP_all 0.3390272849676415
# 5 catboost_top_3_hdp_lda 0.3381632671982172
# 6 catboost_top_3_all 0.33627280522719694
# 7 xgboost_hdp_lda 0.32426136179171317
# 8 catboost_hdp 0.32015983370924594
# 9 MLP_hdp_lda 0.31834343132677434
# 10 xgboost_all 0.31241529455647604
# 11 catboost_all 0.28882339888771347
# 12 best_2018 0.252

# %%
(kek.values[0]/kek.values[9]+kek.values[1]/kek.values[4]+kek.values[2]/kek.values[7]+kek.values[3]/kek.values[10]+kek.values[5]/kek.values[8]+kek.values[6]/kek.values[11]-6)/6
# Out:
# 0.15204835517650128

# %%
clrs = []
for res in result['human'].sort_values(ascending=False).index:
    if 'top_3' in res:
        clrs.append('Yes')
    elif 'best' in res:
        clrs.append('best')
    else:
        clrs.append('No')
color_dict = {'Yes':'red', 'No':'blue','best':'green'}
bars = result['human'].sort_values(ascending=False).astype(float).plot.bar(x='models',y='Rouge-2-f1',title='System summaries vs. Human summaries',grid=True, color=[color_dict[r] for r in clrs])
plt.ylabel('Rouge-2-f1')
plt.xlabel('models')
plt.show()
list(result['human'].sort_values(ascending=False).index[:3])
# Out:
# ['catboost_top_3_hdp_lda', 'MLP_top_3_hdp_lda', 'MLP_hdp_lda']

# %%
kek = result['human'].sort_values(ascending=False).astype(float)
for (i, j),ind in zip(enumerate(kek),kek.index):
    print(i,ind, j)
# Out:
# 0 catboost_top_3_hdp_lda 0.23864429378536958
# 1 MLP_top_3_hdp_lda 0.22887144739488954
# 2 MLP_hdp_lda 0.22430687418319506
# 3 MLP_top_3_all 0.2198220265613308
# 4 xgboost_top_3_hdp_lda 0.21540396886013197
# 5 catboost_top_3_all 0.21403042532207833
# 6 best_2018 0.213
# 7 xgboost_top_3_all 0.20672613209210627
# 8 catboost_hdp 0.19824910801274004
# 9 MLP_all 0.19407388766975492
# 10 catboost_all 0.18636222070100222
# 11 xgboost_all 0.1579678258162968
# 12 xgboost_hdp_lda 0.15410472639000478

# %%
(kek.values[0]/kek.values[8]+kek.values[1]/kek.values[2]+kek.values[3]/kek.values[9]+kek.values[4]/kek.values[11]+kek.values[5]/kek.values[10]+kek.values[7]/kek.values[11]-6)/6
# Out:
# 0.19624992959486676

# %%
kek.values[0]/kek.values[8]
# Out:
# 1.2037597353024845

# %%
kek.values[1]/kek.values[2]
# Out:
# 1.0203496804470047

# %%
kek.values[3]/kek.values[9]
# Out:
# 1.1326718354577927

# %%
kek.values[4]/kek.values[11]
# Out:
# 1.363593932796344

# %%
kek.values[5]/kek.values[10]
# Out:
# 1.148464664764146

# %%
kek.values[7]/kek.values[11]
# Out:
# 1.3086597288014286
